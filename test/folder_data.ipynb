# %%
df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/external-catalog-gcp/external-schema-de-gcp/external-volume-gcp/Employee_Attrition.csv")
display(df)
